# %% [markdown]
# Percobaan kedua membuat model CNN menggunakan Keras </br>
# Training dilakukan dengan 100 epochs </br>
# Model yang dihasilkan punya akurasi validasi (test) 78%. Nilai tersebut diperoleh pada epoch ke 79 </br>
# History dari training disimpan di file historyModel2 </br>

# %% [markdown]
# <h2> ====IMPORT LIBRARY==== </h2>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout,SpatialDropout2D
from tensorflow.keras.models  import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img 
import numpy as np
import os
import time
import glob
import pickle
import matplotlib.pyplot as plt
# Out:
# D:\Anaconda\envs\tubes-tf\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda\envs\tubes-tf\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda\envs\tubes-tf\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda\envs\tubes-tf\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda\envs\tubes-tf\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda\envs\tubes-tf\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
#Cek GPU yang akan dipakai
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11629433730249942305
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3220452147
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15400287210286254129
# physical_device_desc: "device: 0, name: GeForce 940MX, pci bus id: 0000:01:00.0, compute capability: 5.0"
# ]

# %%
os.listdir(os.path.join(os.getcwd(), "dataset-resized"))
# Out:
# ['.DS_Store', 'cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# <h2>====DATASET INPUT====</h2>

# %%
path = "dataset-resized"
listImage = glob.glob(os.path.join(path, '*/*.jpg'))
print("Jumlah dataset: " + str(len(listImage)))
# Out:
# Jumlah dataset: 2527

# %% [markdown]
# <h2> ====IMAGE AUGMENTATION==== </h2>
#
# Membuat image augmentation pada dataset yang sudah ada untuk memperbanyak jumlah dataset</br>
# Membagi dataset yang ada menjadi dataset untuk training dan test </br>

# %%
train = ImageDataGenerator(horizontal_flip=True,
                          vertical_flip=True,
                          validation_split=0.1,
                          rescale=1./255,
                          shear_range=0.1,
                          zoom_range=0.1,
                          width_shift_range=0.1,
                          height_shift_range=0.1)

test = ImageDataGenerator(rescale=1/255, validation_split=0.1)

train_generator = train.flow_from_directory(path, 
                                            target_size=(300,300),
                                            batch_size=32,
                                            class_mode="categorical",
                                            subset="training")

test_generator = test.flow_from_directory(path,
                                          target_size=(300,300),
                                          batch_size=32,
                                          class_mode="categorical",
                                          subset="validation")

#label untuk image
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 2276 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
for img,label in train_generator:
    break
img.shape, label.shape
# Out:
# ((32, 300, 300, 3), (32, 6))

# %%
Labels = '\n'.join(sorted(train_generator.class_indices.keys()))
#with open('labels.txt', 'w') as file:
#    file.write(Labels)

# %% [markdown]
# <h2> ====CNN (Convolutional Neural Network)==== </h2>
#
# Membuat model CNN

# %%
model = Sequential()

model.add(Conv2D(32,(3,3), padding="same", input_shape=(300,300,3), activation="relu"))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())

model.add(Dense(64, activation="relu"))
model.add(Dense(6, activation="softmax"))

#menyimpan model
modelFile = "modelConfig2.h5"
checkpoint1 = ModelCheckpoint(modelFile, monitor="val_acc", verbose=1, save_best_only=True, mode="max")
callback_list = [checkpoint1]

# %%
#konfigurasi model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 300, 300, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 43808)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2803776
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 2,842,022
# Trainable params: 2,842,022
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["acc"])

# %% [markdown]
# <h2>====TRAINING====</h2>

# %%
# %%time
history = model.fit_generator(train_generator,
                              epochs=100,
                              steps_per_epoch=2276//32,
                              validation_data=test_generator,
                              validation_steps=251//32,
                              workers=4,
                              callbacks=callback_list)
# Out:
# Epoch 1/100
# 70/71 [============================>.] - ETA: 1s - loss: 1.7308 - acc: 0.2772
# Epoch 00001: val_acc improved from -inf to 0.23661, saving model to modelConfig2.h5
# 71/71 [==============================] - 88s 1s/step - loss: 1.7309 - acc: 0.2764 - val_loss: 1.7227 - val_acc: 0.2366
# Epoch 2/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.6775 - acc: 0.2562
# Epoch 00002: val_acc improved from 0.23661 to 0.25446, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 929ms/step - loss: 1.6773 - acc: 0.2561 - val_loss: 1.6135 - val_acc: 0.2545
# Epoch 3/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.4730 - acc: 0.4000
# Epoch 00003: val_acc improved from 0.25446 to 0.41518, saving model to modelConfig2.h5
# 71/71 [==============================] - 67s 939ms/step - loss: 1.4722 - acc: 0.3992 - val_loss: 1.4553 - val_acc: 0.4152
# Epoch 4/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.3244 - acc: 0.4795
# Epoch 00004: val_acc improved from 0.41518 to 0.48214, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 936ms/step - loss: 1.3206 - acc: 0.4806 - val_loss: 1.3008 - val_acc: 0.4821
# Epoch 5/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.2596 - acc: 0.4884
# Epoch 00005: val_acc improved from 0.48214 to 0.49554, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 933ms/step - loss: 1.2588 - acc: 0.4881 - val_loss: 1.2783 - val_acc: 0.4955
# Epoch 6/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.2342 - acc: 0.5085
# Epoch 00006: val_acc did not improve from 0.49554
# 71/71 [==============================] - 66s 933ms/step - loss: 1.2347 - acc: 0.5079 - val_loss: 1.4245 - val_acc: 0.4509
# Epoch 7/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.1801 - acc: 0.5397
# Epoch 00007: val_acc did not improve from 0.49554
# 71/71 [==============================] - 66s 931ms/step - loss: 1.1807 - acc: 0.5391 - val_loss: 1.4027 - val_acc: 0.4554
# Epoch 8/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.1359 - acc: 0.5679
# Epoch 00008: val_acc improved from 0.49554 to 0.52679, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 934ms/step - loss: 1.1353 - acc: 0.5678 - val_loss: 1.1637 - val_acc: 0.5268
# Epoch 9/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.1206 - acc: 0.5826
# Epoch 00009: val_acc improved from 0.52679 to 0.56250, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 936ms/step - loss: 1.1240 - acc: 0.5828 - val_loss: 1.1823 - val_acc: 0.5625
# Epoch 10/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.0557 - acc: 0.5996
# Epoch 00010: val_acc improved from 0.56250 to 0.57589, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 935ms/step - loss: 1.0572 - acc: 0.5999 - val_loss: 1.1882 - val_acc: 0.5759
# Epoch 11/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.0743 - acc: 0.5973
# Epoch 00011: val_acc did not improve from 0.57589
# 71/71 [==============================] - 66s 933ms/step - loss: 1.0740 - acc: 0.5973 - val_loss: 1.2098 - val_acc: 0.5179
# Epoch 12/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.0160 - acc: 0.6241
# Epoch 00012: val_acc improved from 0.57589 to 0.58929, saving model to modelConfig2.h5
# 71/71 [==============================] - 67s 945ms/step - loss: 1.0159 - acc: 0.6246 - val_loss: 1.1538 - val_acc: 0.5893
# Epoch 13/100
# 70/71 [============================>.] - ETA: 0s - loss: 1.0116 - acc: 0.6304
# Epoch 00013: val_acc improved from 0.58929 to 0.59821, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 932ms/step - loss: 1.0164 - acc: 0.6289 - val_loss: 1.0774 - val_acc: 0.5982
# Epoch 14/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.9684 - acc: 0.6549
# Epoch 00014: val_acc improved from 0.59821 to 0.62054, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 925ms/step - loss: 0.9679 - acc: 0.6553 - val_loss: 1.0392 - val_acc: 0.6205
# Epoch 15/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.9517 - acc: 0.6513
# Epoch 00015: val_acc did not improve from 0.62054
# 71/71 [==============================] - 66s 934ms/step - loss: 0.9531 - acc: 0.6513 - val_loss: 1.1124 - val_acc: 0.5625
# Epoch 16/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.9074 - acc: 0.6679
# Epoch 00016: val_acc did not improve from 0.62054
# 71/71 [==============================] - 66s 933ms/step - loss: 0.9086 - acc: 0.6664 - val_loss: 1.1048 - val_acc: 0.5893
# Epoch 17/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.8991 - acc: 0.6710
# Epoch 00017: val_acc did not improve from 0.62054
# 71/71 [==============================] - 67s 947ms/step - loss: 0.9021 - acc: 0.6708 - val_loss: 1.0291 - val_acc: 0.5893
# Epoch 18/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.9362 - acc: 0.6527
# Epoch 00018: val_acc did not improve from 0.62054
# 71/71 [==============================] - 66s 925ms/step - loss: 0.9387 - acc: 0.6519 - val_loss: 1.0717 - val_acc: 0.5982
# Epoch 19/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.8681 - acc: 0.6746
# Epoch 00019: val_acc did not improve from 0.62054
# 71/71 [==============================] - 66s 932ms/step - loss: 0.8662 - acc: 0.6756 - val_loss: 1.0536 - val_acc: 0.5982
# Epoch 20/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.8682 - acc: 0.6884
# Epoch 00020: val_acc did not improve from 0.62054
# 71/71 [==============================] - 67s 940ms/step - loss: 0.8655 - acc: 0.6901 - val_loss: 1.0838 - val_acc: 0.6116
# Epoch 21/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.8174 - acc: 0.7027
# Epoch 00021: val_acc improved from 0.62054 to 0.66071, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 934ms/step - loss: 0.8184 - acc: 0.7015 - val_loss: 0.9515 - val_acc: 0.6607
# Epoch 22/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7850 - acc: 0.7210
# Epoch 00022: val_acc did not improve from 0.66071
# 71/71 [==============================] - 66s 923ms/step - loss: 0.7840 - acc: 0.7209 - val_loss: 1.0122 - val_acc: 0.6384
# Epoch 23/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7595 - acc: 0.7290
# Epoch 00023: val_acc did not improve from 0.66071
# 71/71 [==============================] - 66s 929ms/step - loss: 0.7635 - acc: 0.7289 - val_loss: 0.9977 - val_acc: 0.6518
# Epoch 24/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7896 - acc: 0.7045
# Epoch 00024: val_acc improved from 0.66071 to 0.67411, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 935ms/step - loss: 0.7903 - acc: 0.7038 - val_loss: 1.0227 - val_acc: 0.6741
# Epoch 25/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7392 - acc: 0.7362
# Epoch 00025: val_acc did not improve from 0.67411
# 71/71 [==============================] - 67s 947ms/step - loss: 0.7412 - acc: 0.7355 - val_loss: 1.0487 - val_acc: 0.6473
# Epoch 26/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7914 - acc: 0.7179
# Epoch 00026: val_acc did not improve from 0.67411
# 71/71 [==============================] - 66s 924ms/step - loss: 0.7903 - acc: 0.7179 - val_loss: 1.0522 - val_acc: 0.6607
# Epoch 27/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7456 - acc: 0.7478
# Epoch 00027: val_acc did not improve from 0.67411
# 71/71 [==============================] - 66s 932ms/step - loss: 0.7474 - acc: 0.7470 - val_loss: 1.0167 - val_acc: 0.6741
# Epoch 28/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7097 - acc: 0.7469
# Epoch 00028: val_acc improved from 0.67411 to 0.69643, saving model to modelConfig2.h5
# 71/71 [==============================] - 67s 944ms/step - loss: 0.7048 - acc: 0.7482 - val_loss: 0.9271 - val_acc: 0.6964
# Epoch 29/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.7205 - acc: 0.7406
# Epoch 00029: val_acc did not improve from 0.69643
# 71/71 [==============================] - 65s 921ms/step - loss: 0.7171 - acc: 0.7422 - val_loss: 0.9641 - val_acc: 0.6607
# Epoch 30/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6874 - acc: 0.7571
# Epoch 00030: val_acc improved from 0.69643 to 0.71875, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 932ms/step - loss: 0.6847 - acc: 0.7579 - val_loss: 0.8658 - val_acc: 0.7188
# Epoch 31/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6337 - acc: 0.7768
# Epoch 00031: val_acc did not improve from 0.71875
# 71/71 [==============================] - 67s 946ms/step - loss: 0.6417 - acc: 0.7764 - val_loss: 0.9783 - val_acc: 0.6652
# Epoch 32/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6926 - acc: 0.7562
# Epoch 00032: val_acc did not improve from 0.71875
# 71/71 [==============================] - 66s 933ms/step - loss: 0.6894 - acc: 0.7579 - val_loss: 0.9019 - val_acc: 0.7009
# Epoch 33/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6283 - acc: 0.7656
# Epoch 00033: val_acc did not improve from 0.71875
# 71/71 [==============================] - 66s 932ms/step - loss: 0.6257 - acc: 0.7672 - val_loss: 0.9909 - val_acc: 0.6830
# Epoch 34/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6431 - acc: 0.7607
# Epoch 00034: val_acc did not improve from 0.71875
# 71/71 [==============================] - 65s 922ms/step - loss: 0.6424 - acc: 0.7610 - val_loss: 0.9583 - val_acc: 0.6741
# Epoch 35/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6045 - acc: 0.7879
# Epoch 00035: val_acc did not improve from 0.71875
# 71/71 [==============================] - 66s 933ms/step - loss: 0.6057 - acc: 0.7870 - val_loss: 0.9467 - val_acc: 0.6920
# Epoch 36/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6070 - acc: 0.7781
# Epoch 00036: val_acc did not improve from 0.71875
# 71/71 [==============================] - 67s 941ms/step - loss: 0.6050 - acc: 0.7786 - val_loss: 0.9834 - val_acc: 0.6786
# Epoch 37/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5965 - acc: 0.7897
# Epoch 00037: val_acc did not improve from 0.71875
# 71/71 [==============================] - 65s 922ms/step - loss: 0.5987 - acc: 0.7896 - val_loss: 1.0519 - val_acc: 0.7009
# Epoch 38/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5486 - acc: 0.8031
# Epoch 00038: val_acc did not improve from 0.71875
# 71/71 [==============================] - 66s 935ms/step - loss: 0.5471 - acc: 0.8032 - val_loss: 0.9237 - val_acc: 0.7188
# Epoch 39/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5767 - acc: 0.7920
# Epoch 00039: val_acc did not improve from 0.71875
# 71/71 [==============================] - 67s 940ms/step - loss: 0.5824 - acc: 0.7896 - val_loss: 1.0510 - val_acc: 0.6875
# Epoch 40/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5455 - acc: 0.8071
# Epoch 00040: val_acc did not improve from 0.71875
# 71/71 [==============================] - 65s 921ms/step - loss: 0.5463 - acc: 0.8058 - val_loss: 0.9956 - val_acc: 0.6786
# Epoch 41/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5437 - acc: 0.8054
# Epoch 00041: val_acc did not improve from 0.71875
# 71/71 [==============================] - 67s 942ms/step - loss: 0.5418 - acc: 0.8063 - val_loss: 0.9763 - val_acc: 0.6741
# Epoch 42/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.6076 - acc: 0.7795
# Epoch 00042: val_acc did not improve from 0.71875
# 71/71 [==============================] - 66s 931ms/step - loss: 0.6117 - acc: 0.7769 - val_loss: 1.0036 - val_acc: 0.6696
# Epoch 43/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5137 - acc: 0.8134
# Epoch 00043: val_acc did not improve from 0.71875
# 71/71 [==============================] - 65s 919ms/step - loss: 0.5185 - acc: 0.8116 - val_loss: 1.0834 - val_acc: 0.7009
# Epoch 44/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5795 - acc: 0.7888
# Epoch 00044: val_acc did not improve from 0.71875
# 71/71 [==============================] - 67s 943ms/step - loss: 0.5766 - acc: 0.7901 - val_loss: 0.9034 - val_acc: 0.7143
# Epoch 45/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4605 - acc: 0.8375
# Epoch 00045: val_acc did not improve from 0.71875
# 71/71 [==============================] - 66s 930ms/step - loss: 0.4629 - acc: 0.8367 - val_loss: 1.0230 - val_acc: 0.7009
# Epoch 46/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5096 - acc: 0.8125
# Epoch 00046: val_acc did not improve from 0.71875
# 71/71 [==============================] - 65s 920ms/step - loss: 0.5093 - acc: 0.8126 - val_loss: 0.9145 - val_acc: 0.6964
# Epoch 47/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5409 - acc: 0.8152
# Epoch 00047: val_acc did not improve from 0.71875
# 71/71 [==============================] - 67s 941ms/step - loss: 0.5412 - acc: 0.8143 - val_loss: 0.9346 - val_acc: 0.6964
# Epoch 48/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5020 - acc: 0.8196
# Epoch 00048: val_acc improved from 0.71875 to 0.72321, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 924ms/step - loss: 0.4988 - acc: 0.8208 - val_loss: 0.9037 - val_acc: 0.7232
# Epoch 49/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4794 - acc: 0.8348
# Epoch 00049: val_acc improved from 0.72321 to 0.72768, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 929ms/step - loss: 0.4773 - acc: 0.8358 - val_loss: 0.8771 - val_acc: 0.7277
# Epoch 50/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4855 - acc: 0.8299
# Epoch 00050: val_acc did not improve from 0.72768
# 71/71 [==============================] - 66s 931ms/step - loss: 0.4829 - acc: 0.8310 - val_loss: 0.9905 - val_acc: 0.7188
# Epoch 51/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4824 - acc: 0.8308
# Epoch 00051: val_acc did not improve from 0.72768
# 71/71 [==============================] - 67s 943ms/step - loss: 0.4832 - acc: 0.8305 - val_loss: 0.9005 - val_acc: 0.7098
# Epoch 52/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4717 - acc: 0.8353
# Epoch 00052: val_acc improved from 0.72768 to 0.74107, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 932ms/step - loss: 0.4744 - acc: 0.8362 - val_loss: 0.9225 - val_acc: 0.7411
# Epoch 53/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4780 - acc: 0.8353
# Epoch 00053: val_acc improved from 0.74107 to 0.74554, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 931ms/step - loss: 0.4800 - acc: 0.8341 - val_loss: 0.8212 - val_acc: 0.7455
# Epoch 54/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.5093 - acc: 0.8174
# Epoch 00054: val_acc did not improve from 0.74554
# 71/71 [==============================] - 66s 929ms/step - loss: 0.5094 - acc: 0.8182 - val_loss: 0.9559 - val_acc: 0.7232
# Epoch 55/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4199 - acc: 0.8576
# Epoch 00055: val_acc did not improve from 0.74554
# 71/71 [==============================] - 65s 919ms/step - loss: 0.4187 - acc: 0.8578 - val_loss: 0.8677 - val_acc: 0.7232
# Epoch 56/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4498 - acc: 0.8446
# Epoch 00056: val_acc did not improve from 0.74554
# 71/71 [==============================] - 66s 930ms/step - loss: 0.4487 - acc: 0.8459 - val_loss: 0.8573 - val_acc: 0.7411
# Epoch 57/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4370 - acc: 0.8433
# Epoch 00057: val_acc did not improve from 0.74554
# 71/71 [==============================] - 67s 938ms/step - loss: 0.4356 - acc: 0.8433 - val_loss: 0.9720 - val_acc: 0.7321
# Epoch 58/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4115 - acc: 0.8558
# Epoch 00058: val_acc did not improve from 0.74554
# 71/71 [==============================] - 66s 928ms/step - loss: 0.4104 - acc: 0.8556 - val_loss: 0.9225 - val_acc: 0.7232
# Epoch 59/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4353 - acc: 0.8442
# Epoch 00059: val_acc did not improve from 0.74554
# 71/71 [==============================] - 66s 931ms/step - loss: 0.4334 - acc: 0.8451 - val_loss: 0.9810 - val_acc: 0.7143
# Epoch 60/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4300 - acc: 0.8442
# Epoch 00060: val_acc did not improve from 0.74554
# 71/71 [==============================] - 66s 929ms/step - loss: 0.4288 - acc: 0.8447 - val_loss: 1.0058 - val_acc: 0.6920
# Epoch 61/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4516 - acc: 0.8384
# Epoch 00061: val_acc did not improve from 0.74554
# 71/71 [==============================] - 65s 919ms/step - loss: 0.4543 - acc: 0.8372 - val_loss: 1.0116 - val_acc: 0.7054
# Epoch 62/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4442 - acc: 0.8545
# Epoch 00062: val_acc did not improve from 0.74554
# 71/71 [==============================] - 67s 937ms/step - loss: 0.4444 - acc: 0.8534 - val_loss: 1.0151 - val_acc: 0.7232
# Epoch 63/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4079 - acc: 0.8513
# Epoch 00063: val_acc did not improve from 0.74554
# 71/71 [==============================] - 66s 928ms/step - loss: 0.4046 - acc: 0.8530 - val_loss: 0.9565 - val_acc: 0.7321
# Epoch 64/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4308 - acc: 0.8433
# Epoch 00064: val_acc improved from 0.74554 to 0.75446, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 933ms/step - loss: 0.4307 - acc: 0.8438 - val_loss: 0.8586 - val_acc: 0.7545
# Epoch 65/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3727 - acc: 0.8750
# Epoch 00065: val_acc did not improve from 0.75446
# 71/71 [==============================] - 66s 930ms/step - loss: 0.3739 - acc: 0.8741 - val_loss: 0.9922 - val_acc: 0.6920
# Epoch 66/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4358 - acc: 0.8558
# Epoch 00066: val_acc improved from 0.75446 to 0.76339, saving model to modelConfig2.h5
# 71/71 [==============================] - 65s 918ms/step - loss: 0.4332 - acc: 0.8566 - val_loss: 0.9025 - val_acc: 0.7634
# Epoch 67/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4180 - acc: 0.8625
# Epoch 00067: val_acc improved from 0.76339 to 0.77232, saving model to modelConfig2.h5
# 71/71 [==============================] - 67s 943ms/step - loss: 0.4138 - acc: 0.8644 - val_loss: 0.8019 - val_acc: 0.7723
# Epoch 68/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.4494 - acc: 0.8379
# Epoch 00068: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 933ms/step - loss: 0.4516 - acc: 0.8372 - val_loss: 0.8518 - val_acc: 0.7366
# Epoch 69/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3908 - acc: 0.8594
# Epoch 00069: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 933ms/step - loss: 0.3886 - acc: 0.8609 - val_loss: 0.8231 - val_acc: 0.7634
# Epoch 70/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3944 - acc: 0.8674
# Epoch 00070: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 930ms/step - loss: 0.3959 - acc: 0.8662 - val_loss: 0.9809 - val_acc: 0.7188
# Epoch 71/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3372 - acc: 0.8835
# Epoch 00071: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 929ms/step - loss: 0.3358 - acc: 0.8842 - val_loss: 0.9943 - val_acc: 0.7366
# Epoch 72/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3831 - acc: 0.8643
# Epoch 00072: val_acc did not improve from 0.77232
# 71/71 [==============================] - 65s 920ms/step - loss: 0.3835 - acc: 0.8644 - val_loss: 0.7786 - val_acc: 0.7500
# Epoch 73/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3625 - acc: 0.8719
# Epoch 00073: val_acc did not improve from 0.77232
# 71/71 [==============================] - 65s 919ms/step - loss: 0.3594 - acc: 0.8732 - val_loss: 0.8921 - val_acc: 0.7411
# Epoch 74/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3407 - acc: 0.8799
# Epoch 00074: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 926ms/step - loss: 0.3401 - acc: 0.8789 - val_loss: 1.0434 - val_acc: 0.7009
# Epoch 75/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3359 - acc: 0.8772
# Epoch 00075: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 926ms/step - loss: 0.3353 - acc: 0.8776 - val_loss: 0.8468 - val_acc: 0.7589
# Epoch 76/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3400 - acc: 0.8786
# Epoch 00076: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 926ms/step - loss: 0.3409 - acc: 0.8767 - val_loss: 1.0435 - val_acc: 0.7455
# Epoch 77/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3641 - acc: 0.8759
# Epoch 00077: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 929ms/step - loss: 0.3614 - acc: 0.8772 - val_loss: 1.0567 - val_acc: 0.6696
# Epoch 78/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3811 - acc: 0.8629
# Epoch 00078: val_acc did not improve from 0.77232
# 71/71 [==============================] - 66s 924ms/step - loss: 0.3803 - acc: 0.8636 - val_loss: 1.0749 - val_acc: 0.7054
# Epoch 79/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3689 - acc: 0.8723
# Epoch 00079: val_acc improved from 0.77232 to 0.78571, saving model to modelConfig2.h5
# 71/71 [==============================] - 66s 928ms/step - loss: 0.3655 - acc: 0.8737 - val_loss: 0.8553 - val_acc: 0.7857
# Epoch 80/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3147 - acc: 0.8830
# Epoch 00080: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 928ms/step - loss: 0.3206 - acc: 0.8812 - val_loss: 0.9015 - val_acc: 0.7411
# Epoch 81/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3324 - acc: 0.8844
# Epoch 00081: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 926ms/step - loss: 0.3369 - acc: 0.8842 - val_loss: 0.9563 - val_acc: 0.7411
# Epoch 82/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3341 - acc: 0.8862
# Epoch 00082: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 936ms/step - loss: 0.3333 - acc: 0.8860 - val_loss: 0.8903 - val_acc: 0.7634
# Epoch 83/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3491 - acc: 0.8844
# Epoch 00083: val_acc did not improve from 0.78571
# 71/71 [==============================] - 65s 918ms/step - loss: 0.3486 - acc: 0.8838 - val_loss: 0.9400 - val_acc: 0.7411
# Epoch 84/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2878 - acc: 0.8938
# Epoch 00084: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 928ms/step - loss: 0.2855 - acc: 0.8948 - val_loss: 0.9218 - val_acc: 0.7366
# Epoch 85/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3101 - acc: 0.8911
# Epoch 00085: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 929ms/step - loss: 0.3100 - acc: 0.8904 - val_loss: 1.0870 - val_acc: 0.7321
# Epoch 86/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3106 - acc: 0.8924
# Epoch 00086: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 927ms/step - loss: 0.3144 - acc: 0.8904 - val_loss: 1.0054 - val_acc: 0.7366
# Epoch 87/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3394 - acc: 0.8862
# Epoch 00087: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 931ms/step - loss: 0.3382 - acc: 0.8864 - val_loss: 0.8456 - val_acc: 0.7812
# Epoch 88/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3151 - acc: 0.8933
# Epoch 00088: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 926ms/step - loss: 0.3133 - acc: 0.8943 - val_loss: 0.9696 - val_acc: 0.7679
# Epoch 89/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2820 - acc: 0.9062
# Epoch 00089: val_acc did not improve from 0.78571
# 71/71 [==============================] - 67s 940ms/step - loss: 0.2818 - acc: 0.9067 - val_loss: 0.8582 - val_acc: 0.7500
# Epoch 90/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3009 - acc: 0.8955
# Epoch 00090: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 929ms/step - loss: 0.3039 - acc: 0.8952 - val_loss: 1.0366 - val_acc: 0.7054
# Epoch 91/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3756 - acc: 0.8746
# Epoch 00091: val_acc did not improve from 0.78571
# 71/71 [==============================] - 65s 915ms/step - loss: 0.3736 - acc: 0.8750 - val_loss: 0.7397 - val_acc: 0.7679
# Epoch 92/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2972 - acc: 0.8933
# Epoch 00092: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 925ms/step - loss: 0.2986 - acc: 0.8931 - val_loss: 1.1059 - val_acc: 0.7232
# Epoch 93/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2988 - acc: 0.8938
# Epoch 00093: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 929ms/step - loss: 0.2964 - acc: 0.8948 - val_loss: 0.8565 - val_acc: 0.7723
# Epoch 94/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2825 - acc: 0.8991
# Epoch 00094: val_acc did not improve from 0.78571
# 71/71 [==============================] - 67s 940ms/step - loss: 0.2812 - acc: 0.8996 - val_loss: 0.9655 - val_acc: 0.7634
# Epoch 95/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.3202 - acc: 0.8960
# Epoch 00095: val_acc did not improve from 0.78571
# 71/71 [==============================] - 65s 917ms/step - loss: 0.3189 - acc: 0.8966 - val_loss: 0.9330 - val_acc: 0.7723
# Epoch 96/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2762 - acc: 0.9000
# Epoch 00096: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 931ms/step - loss: 0.2786 - acc: 0.8997 - val_loss: 0.8144 - val_acc: 0.7455
# Epoch 97/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2778 - acc: 0.9116
# Epoch 00097: val_acc did not improve from 0.78571
# 71/71 [==============================] - 67s 938ms/step - loss: 0.2765 - acc: 0.9120 - val_loss: 0.9358 - val_acc: 0.7679
# Epoch 98/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2802 - acc: 0.9004
# Epoch 00098: val_acc did not improve from 0.78571
# 71/71 [==============================] - 65s 917ms/step - loss: 0.2782 - acc: 0.9010 - val_loss: 1.0121 - val_acc: 0.7679
# Epoch 99/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2654 - acc: 0.9134
# Epoch 00099: val_acc did not improve from 0.78571
# 71/71 [==============================] - 66s 929ms/step - loss: 0.2640 - acc: 0.9142 - val_loss: 0.9026 - val_acc: 0.7411
# Epoch 100/100
# 70/71 [============================>.] - ETA: 0s - loss: 0.2754 - acc: 0.9036
# Epoch 00100: val_acc did not improve from 0.78571
# 71/71 [==============================] - 67s 940ms/step - loss: 0.2764 - acc: 0.9027 - val_loss: 0.9764 - val_acc: 0.7857
# Wall time: 1h 50min 31s

# %%
#save history ke file
with open('historyModel2', 'wb') as f :
    pickle.dump(history.history, f)

# %%
train_acc = history.history['acc']
validation_acc = history.history['val_acc']

train_loss = history.history['loss']
validation_loss = history.history['val_loss']

#plot grafik akurasi
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(validation_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

#plot grafik loss
plt.subplot(2, 1, 2)
plt.plot(train_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()
